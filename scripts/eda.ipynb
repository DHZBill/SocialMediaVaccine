# %%
import numpy as np
import pandas as pd

# %%
TWEET_PATH = '../data/vaccination_all_tweets.csv'
GEO_PATH = '../data/country_vaccinations.csv'
ANNOTATED_PATH = '../data/covid_vaccine_tweets_with_sentiment.csv'

# %%
tweets = pd.read_csv(TWEET_PATH)
geo = pd.read_csv(GEO_PATH)

# %%
tweets.head(10)
# Out:
#                     id             user_name                user_location  \
# 0  1340539111971516416            Rachel Roh    La Crescenta-Montrose, CA
# 1  1338158543359250433           Albert Fong            San Francisco, CA
# 2  1337858199140118533              eli🇱🇹🇪🇺👌                     Your Bed
# 3  1337855739918835717         Charles Adler       Vancouver, BC - Canada
# 4  1337854064604966912  Citizen News Channel                          NaN
# 5  1337852648389832708                   Dee          Birmingham, England
# 6  1337851215875608579     Gunther Fehlinger  Austria, Ukraine and Kosovo
# 7  1337850832256176136   Dr.Krutika Kuppalli                          NaN
# 8  1337850023531347969           Erin Despas                          NaN
# 9  1337842295857623042          Ch.Amjad Ali                    Islamabad
#
#                                     user_description         user_created  \
# 0  Aggregator of Asian American news; scanning di...  2009-04-08 17:52:46
# ...

# %%
geo[geo['country']=="United Kingdom"].head(10)
# Out:
#               country iso_code        date  total_vaccinations  \
# 50032  United Kingdom      GBR  2021-01-10           2677971.0
# 50033  United Kingdom      GBR  2021-01-11           2843815.0
# 50034  United Kingdom      GBR  2021-01-12           3067541.0
# 50035  United Kingdom      GBR  2021-01-13           3356229.0
# 50036  United Kingdom      GBR  2021-01-14           3678180.0
# 50037  United Kingdom      GBR  2021-01-15           4023705.0
# 50038  United Kingdom      GBR  2021-01-16           4322456.0
# 50039  United Kingdom      GBR  2021-01-17           4514802.0
# 50040  United Kingdom      GBR  2021-01-18           4723443.0
# 50041  United Kingdom      GBR  2021-01-19           5070365.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 50032          2286572.0                 391399.0                     NaN
# 50033          2431648.0                 412167.0                165844.0
# ...

# %%
pfizer = tweets[tweets['text'].str.contains('pfizer|Pfizer')]
moderna = tweets[tweets['text'].str.contains('moderna|Moderna')]

print(pfizer.count(), moderna.count())
# Out:
# id                  20830
# user_name           20830
# user_location       15593
# user_description    19255
# user_created        20830
# user_followers      20830
# user_friends        20830
# user_favourites     20830
# user_verified       20830
# date                20830
# text                20830
# hashtags            19027
# source              20829
# retweets            20830
# favorites           20830
# is_retweet          20830
# dtype: int64 id                  44403
# user_name           44403
# user_location       34429
# user_description    41608
# user_created        44403
# user_followers      44403
# user_friends        44403
# user_favourites     44403
# user_verified       44403
# date                44403
# text                44403
# hashtags            41298
# source              44297
# retweets            44403
# favorites           44403
# is_retweet          44403
# dtype: int64

# %%
china = tweets[tweets['text'].str.contains('sinopharm|sinovac|Sinopharm|Sinovac')]
china.count()
# Out:
# id                  18271
# user_name           18271
# user_location       14001
# user_description    16612
# user_created        18271
# user_followers      18271
# user_friends        18271
# user_favourites     18271
# user_verified       18271
# date                18271
# text                18271
# hashtags            17270
# source              18271
# retweets            18271
# favorites           18271
# is_retweet          18271
# dtype: int64

# %%
print(china.text.head(10))
china.user_location.value_counts()
# Out:
# 325     Turkey’s death toll from COVID-19 rises to 16,...
# 341     Turkey’s death toll from COVID-19 rises to 16,...
# 412     @DrTonyLeachon @ralphrecto why this government...
# 455     We should have this photo pinned for everyone’...
# 584     Global coronavirus death toll surpasses 1,64 m...
# 621     Global coronavirus death toll surpasses 1,64 m...
# 849     #COVAX #ThePeoplesVaccine #COVID19 #Moderna #S...
# 1048    On the other news, while @SecDuque and Rodrigo...
# 1496    China's Sinovac COVID-19 vaccine proves effect...
# 1805    DO NOT TAKE THE VACCINE.\nhttps://t.co/MnqAyck...
# Name: text, dtype: object
# Beijing, China        776
# Sri Lanka             653
# Beijing               481
# Colombo, Sri Lanka    421
# Malaysia              264
#                      ...
# Shenzhen - China        1
# São Paulo, Brasil       1
# Antwerpen, Belgium      1
# No                      1
# 43.9K//SLGR             1
# Name: user_location, Length: 3299, dtype: int64

# %%
sentiments = pd.read_csv(ANNOTATED_PATH)
print(sentiments.iloc[4].tweet_text)
# Out:
# Lab studies suggest #Pfizer, #Moderna vaccines can protect against #coronavirusvariant
# https://t.co/NPaFA68m57
